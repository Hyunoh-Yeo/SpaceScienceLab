# %%
# Imports
import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import sklearn as sk

# %%
# Unpacking data to useable form for pd

f = open("DLL_zenodo_1998_T1h.txt", "r")
#f.read(50)

lines = [next(f) for _ in range(408134)]  # first 100 lines
remainder_of_file = f.read()  
f.close()

# %%
dataframe = []
for line in lines[21:]:
    data = line.split()
    dataframe.append(data)
    
df = pd.DataFrame(dataframe, columns = ["Date", "Day-of-year", "Time", "hourly avg location for the magnetopause B_barre", "hourly variance for the magnetopause", "lifetime for the autocorrelation function", "magnitude for radial diffusion"] )
df
# Out:
#               Date Day-of-year   Time  \
# 0       1998/01/01         001  00:52
# 1       1998/01/01         001  00:53
# 2       1998/01/01         001  00:54
# 3       1998/01/01         001  00:57
# 4       1998/01/01         001  00:58
# ...            ...         ...    ...
# 408108  1998/12/13         347  23:03
# 408109  1998/12/13         347  23:04
# 408110  1998/12/13         347  23:05
# 408111  1998/12/13         347  23:06
# 408112  1998/12/13         347  23:07
#
#        hourly avg location for the magnetopause B_barre  \
# 0                                              1.02e+01
# 1                                              1.02e+01
# 2                                              1.02e+01
# 3                                              1.02e+01
# 4                                              1.02e+01
# ...                                                 ...
# 408108                                         9.15e+00
# 408109                                         9.15e+00
# 408110                                         9.15e+00
# 408111                                         9.15e+00
# 408112                                         9.15e+00
#
#        hourly variance for the magnetopause  \
# 0                                  2.00e-02
# 1                                  1.98e-02
# 2                                  1.94e-02
# 3                                  2.03e-02
# 4                                  2.02e-02
# ...                                     ...
# 408108                             1.74e-02
# 408109                             1.80e-02
# 408110                             1.71e-02
# 408111                             1.55e-02
# 408112                             1.46e-02
#
#        lifetime for the autocorrelation function  \
# 0                                       1.72e+00
# 1                                       1.81e+00
# 2                                       1.77e+00
# 3                                       1.71e+00
# 4                                       1.78e+00
# ...                                          ...
# 408108                                  3.44e+00
# 408109                                  2.81e+00
# 408110                                  2.50e+00
# 408111                                  2.30e+00
# 408112                                  2.31e+00
#
#        magnitude for radial diffusion
# 0                           -8.67e+00
# 1                           -8.65e+00
# 2                           -8.67e+00
# 3                           -8.66e+00
# 4                           -8.65e+00
# ...                               ...
# 408108                      -7.94e+00
# 408109                      -8.01e+00
# 408110                      -8.08e+00
# 408111                      -8.16e+00
# 408112                      -8.19e+00
#
# [408113 rows x 7 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=28a83fbe-9ed8-4ad0-ab71-9db262ace005' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
