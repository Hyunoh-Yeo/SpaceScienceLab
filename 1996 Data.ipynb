# %%
# Imports
import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import sklearn as sk

# %%
# Unpacking data to useable form for pd

f = open("DLL_zenodo_1996_T1h.txt", "r")
#f.read(50)

lines = [next(f) for _ in range(416000)]  # first 100 lines
remainder_of_file = f.read()  
f.close()

# %%
dataframe = []
for line in lines[21:]:
    data = line.split()
    dataframe.append(data)
    
df = pd.DataFrame(dataframe, columns = ["Date", "Day-of-year", "Time", "hourly avg location for the magnetopause B_barre", "hourly variance for the magnetopause", "lifetime for the autocorrelation function", "magnitude for radial diffusion"] )
df
# Out:
#               Date Day-of-year   Time  \
# 0       1996/01/01         001  00:47
# 1       1996/01/01         001  00:48
# 2       1996/01/01         001  00:49
# 3       1996/01/01         001  00:50
# 4       1996/01/01         001  00:51
# ...            ...         ...    ...
# 408108  1996/12/21         356  23:15
# 408109  1996/12/21         356  23:16
# 408110  1996/12/21         356  23:17
# 408111  1996/12/21         356  23:18
# 408112  1996/12/21         356  23:19
#
#        hourly avg location for the magnetopause B_barre  \
# 0                                              1.00e+01
# 1                                              1.00e+01
# 2                                              1.00e+01
# 3                                              1.00e+01
# 4                                              1.00e+01
# ...                                                 ...
# 408108                                         1.09e+01
# ...

# %%
_dntk.DeepnoteChart(df, """{"data":{"name":"placeholder"},"mark":{"type":"bar","tooltip":true},"height":220,"$schema":"https://vega.github.io/schema/vega-lite/v4.json","autosize":{"type":"fit"},"encoding":{"x":{"sort":null,"type":"nominal","field":"Date","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"nominal","field":"Day-of-year","scale":{"type":"linear","zero":true}},"color":{"sort":null,"type":"nominal","field":"","scale":{"type":"linear","zero":false}}}}""")
# Out:
# alt.Chart(...)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=28a83fbe-9ed8-4ad0-ab71-9db262ace005' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
