# %%
# loading in various datasets
# imports!
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
import datetime
from scipy.stats import iqr

# %%
# load in DLL 96 data

f = open("DLL_zenodo_1996_T1h.txt", "r")

lines = [next(f) for _ in range(417845)]
remainder_of_file = f.read()  
f.close()

#making a nested list - possible implemmentation 
dataframe = []
for line in lines[21:]:
    data = line.split()
    dataframe.append(data)
    
df_1996 = pd.DataFrame(dataframe, columns = ["Date", "Day-of-year", "Time", "hourly avg location for the magnetopause B_barre", "hourly variance for the magnetopause", "lifetime for the autocorrelation function", "magnitude for radial diffusion"] )
df_1996
# Out:
#               Date Day-of-year   Time  \
# 0       1996/01/01         001  00:47
# 1       1996/01/01         001  00:48
# 2       1996/01/01         001  00:49
# 3       1996/01/01         001  00:50
# 4       1996/01/01         001  00:51
# ...            ...         ...    ...
# 417819  1996/12/30         365  05:10
# 417820  1996/12/30         365  05:11
# 417821  1996/12/30         365  05:13
# 417822  1996/12/30         365  05:14
# 417823  1996/12/30         365  05:19
#
#        hourly avg location for the magnetopause B_barre  \
# 0                                              1.00e+01
# 1                                              1.00e+01
# 2                                              1.00e+01
# 3                                              1.00e+01
# 4                                              1.00e+01
# ...                                                 ...
# 417819                                         8.79e+00
# 417820                                         8.79e+00
# 417821                                         8.79e+00
# 417822                                         8.79e+00
# 417823                                         8.79e+00
#
#        hourly variance for the magnetopause  \
# 0                                  1.25e-02
# 1                                  1.47e-02
# 2                                  1.46e-02
# 3                                  1.43e-02
# 4                                  1.40e-02
# ...                                     ...
# 417819                             1.77e-02
# 417820                             1.77e-02
# 417821                             1.79e-02
# 417822                             1.75e-02
# 417823                             1.81e-02
#
#        lifetime for the autocorrelation function  \
# 0                                       1.40e+00
# 1                                       1.73e+00
# 2                                       1.96e+00
# 3                                       2.05e+00
# 4                                       2.08e+00
# ...                                          ...
# 417819                                  1.02e+00
# 417820                                  1.03e+00
# 417821                                  1.02e+00
# 417822                                  1.08e+00
# 417823                                  1.10e+00
#
#        magnitude for radial diffusion
# 0                           -8.87e+00
# 1                           -8.70e+00
# 2                           -8.65e+00
# 3                           -8.64e+00
# 4                           -8.65e+00
# ...                               ...
# 417819                      -8.28e+00
# 417820                      -8.28e+00
# 417821                      -8.28e+00
# 417822                      -8.26e+00
# 417823                      -8.24e+00
#
# [417824 rows x 7 columns]

# %%
# load in DLL98 data

f = open("DLL_zenodo_1998_T1h.txt", "r")

lines = [next(f) for _ in range(425276)]
remainder_of_file = f.read()  
f.close()

#making a nested list - possible implemmentation 
dataframe = []
for line in lines[21:]:
    data = line.split()
    dataframe.append(data)
    
df_1998 = pd.DataFrame(dataframe, columns = ["Date", "Day-of-year", "Time", "hourly avg location for the magnetopause B_barre", "hourly variance for the magnetopause", "lifetime for the autocorrelation function", "magnitude for radial diffusion"] )
df_1998
# Out:
#               Date Day-of-year   Time  \
# 0       1998/01/01         001  00:52
# 1       1998/01/01         001  00:53
# 2       1998/01/01         001  00:54
# 3       1998/01/01         001  00:57
# 4       1998/01/01         001  00:58
# ...            ...         ...    ...
# 425250  1998/12/31         365  23:47
# 425251  1998/12/31         365  23:52
# 425252  1998/12/31         365  23:53
# 425253  1998/12/31         365  23:54
# 425254  1998/12/31         365  23:55
#
#        hourly avg location for the magnetopause B_barre  \
# 0                                              1.02e+01
# 1                                              1.02e+01
# 2                                              1.02e+01
# 3                                              1.02e+01
# 4                                              1.02e+01
# ...                                                 ...
# 425250                                         1.02e+01
# 425251                                         1.02e+01
# 425252                                         1.02e+01
# 425253                                         1.02e+01
# 425254                                         1.02e+01
#
#        hourly variance for the magnetopause  \
# 0                                  2.00e-02
# 1                                  1.98e-02
# 2                                  1.94e-02
# 3                                  2.03e-02
# 4                                  2.02e-02
# ...                                     ...
# 425250                             1.47e-02
# 425251                             1.40e-02
# 425252                             1.40e-02
# 425253                             1.40e-02
# 425254                             1.40e-02
#
#        lifetime for the autocorrelation function  \
# 0                                       1.72e+00
# 1                                       1.81e+00
# 2                                       1.77e+00
# 3                                       1.71e+00
# 4                                       1.78e+00
# ...                                          ...
# 425250                                  1.98e+00
# 425251                                  2.26e+00
# 425252                                  2.30e+00
# 425253                                  2.29e+00
# 425254                                  2.30e+00
#
#        magnitude for radial diffusion
# 0                           -8.67e+00
# 1                           -8.65e+00
# 2                           -8.67e+00
# 3                           -8.66e+00
# 4                           -8.65e+00
# ...                               ...
# 425250                      -8.73e+00
# 425251                      -8.69e+00
# 425252                      -8.68e+00
# 425253                      -8.68e+00
# 425254                      -8.68e+00
#
# [425255 rows x 7 columns]

# %%
# using these two datasets, use our

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=28a83fbe-9ed8-4ad0-ab71-9db262ace005' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
