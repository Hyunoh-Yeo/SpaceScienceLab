# %%
# Imports
import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import sklearn as sk

# %%
# Unpacking data to useable form for pd

f = open("DLL_zenodo_1997_T1h.txt", "r")
#f.read(50)

lines = [next(f) for _ in range(408134)]  # first 100 lines
remainder_of_file = f.read()  
f.close()

# %%
dataframe = []
for line in lines[21:]:
    data = line.split()
    dataframe.append(data)
    
df = pd.DataFrame(dataframe, columns = ["Date", "Day-of-year", "Time", "hourly avg location for the magnetopause B_barre", "hourly variance for the magnetopause", "lifetime for the autocorrelation function", "magnitude for radial diffusion"] )
df
# Out:
#               Date Day-of-year   Time  \
# 0       1997/01/01         001  18:31
# 1       1997/01/01         001  18:32
# 2       1997/01/01         001  18:33
# 3       1997/01/01         001  18:34
# 4       1997/01/01         001  18:35
# ...            ...         ...    ...
# 408108  1997/12/17         351  19:40
# 408109  1997/12/17         351  19:42
# 408110  1997/12/17         351  19:43
# 408111  1997/12/17         351  19:44
# 408112  1997/12/17         351  19:45
#
#        hourly avg location for the magnetopause B_barre  \
# 0                                              1.06e+01
# 1                                              1.06e+01
# 2                                              1.06e+01
# 3                                              1.06e+01
# 4                                              1.06e+01
# ...                                                 ...
# 408108                                         9.80e+00
# 408109                                         9.80e+00
# 408110                                         9.80e+00
# 408111                                         9.80e+00
# 408112                                         9.80e+00
#
#        hourly variance for the magnetopause  \
# 0                                  6.66e-02
# 1                                  6.51e-02
# 2                                  6.34e-02
# 3                                  6.23e-02
# 4                                  6.67e-02
# ...                                     ...
# 408108                             8.45e-03
# 408109                             8.83e-03
# 408110                             8.83e-03
# 408111                             9.27e-03
# 408112                             9.26e-03
#
#        lifetime for the autocorrelation function  \
# 0                                       1.28e+00
# 1                                       1.24e+00
# 2                                       1.24e+00
# 3                                       1.23e+00
# 4                                       1.20e+00
# ...                                          ...
# 408108                                  2.07e+00
# 408109                                  2.07e+00
# 408110                                  2.07e+00
# 408111                                  1.95e+00
# 408112                                  1.96e+00
#
#        magnitude for radial diffusion
# 0                           -8.43e+00
# 1                           -8.45e+00
# 2                           -8.46e+00
# 3                           -8.47e+00
# 4                           -8.45e+00
# ...                               ...
# 408108                      -8.77e+00
# 408109                      -8.75e+00
# 408110                      -8.75e+00
# 408111                      -8.76e+00
# 408112                      -8.75e+00
#
# [408113 rows x 7 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=28a83fbe-9ed8-4ad0-ab71-9db262ace005' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
